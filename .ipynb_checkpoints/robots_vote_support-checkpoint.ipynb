# %% [markdown]
# # Robots Vote: Do Robots Influence Your Vote?
# **Experiment support code** <br>
# This code supports the experiment, allowing us to control the behavior of the robots.

# %% [markdown]
# ## Getting Started...
# Imports and auxiliary code

# %% [markdown]
# ### Robots

# %%
import asyncio
import soundfile as sf
import numpy as np
from reachy_mini import ReachyMini
from dash.robot import DashRobot, discover_and_connect
import time
import random
from reachy_mini.utils import create_head_pose
import os
import wave
from reachy_mini.motion.recorded_move import RecordedMoves

EMOTIONS_DATASET = "pollen-robotics/reachy-mini-emotions-library"
emotions = RecordedMoves(EMOTIONS_DATASET)


class Robot:
    def __init__(self, name, typer, position):
        self.name = name
        self.type = typer
        self.device = None
        self.audio_path=None
        self.audio_slot=None
        self.dash_orientarion = 0
        self.antenna_angle = 0
        self.state = "idle"
        self.idle_animations_reachy = ["curious1", "thoughtful1", "thoughtful2"]
        self.listen_animations_reachy = ["proud1", "understanding2", "attentive2"]
        self.position = position
        self.value_eye_dash = 0
        if(position == 1):
            self.look_angles = {2: 54, 3:18, 4:-18, 5:-54} 
        if(position == 2):
            self.look_angles = {3: 54, 4:18, 5:-18, 1:-54} 
        if(position == 3):
            self.look_angles = {4: 54, 5:18, 1:-18, 2:-54} 
        if(position == 4):
            self.look_angles = {5: 54, 1:18, 2:-18, 3:-54} 
        self.stare_position = 0
            
        
    async def connect(self):
        try:
            if self.type == "dash": 
                print(f"[{self.name}] A procurar dash...")
                robo = await discover_and_connect([self.name])
                if robo:
                    self.device = robo
            
                
            elif self.type == "reachy":
                print(f"[{self.name}] A procurar Reachy...")
                #self.device = ReachyMini(id=self.name)
                if self.name == "Robot1":
                    self.device = ReachyMini(host="reachy-mini-one.local")
                elif self.name == "Robot2":
                    self.device = ReachyMini(host="reachy-mini-two.local")
                else:
                    self.device = ReachyMini()
                self.device.media.start_playing()
                self.device.goto_target(head=create_head_pose(), duration=0.2)
                
            else:
                print("RobotSim " + self.name + " is connected!")
            print(f"✅ {self.name} connected")
        except Exception as e:
            print(f"❌ Robot {self.name} falied to connect: {e}")

            

    def is_connected(self):
        return self.device is not None or (self.type != "dash" and self.type != "reachy")
    
    def change_audio(self, audio):
        if self.type == "dash":
            self.audio_slot=audio
        elif self.type == "reachy":
            self.audio_path=audio

    async def animete_and_talk(self,duration):
        if self.type == "dash": 
            await self.device.say(self.audio_slot) 
            end = time.time() + duration
            self.device.eye(0)
            while time.time() < end:
                for brilho in [0, 75, 150, 75]:
                        await self.device.eye_brightness(brilho)
                        await asyncio.sleep(0.15)
        elif self.type == "reachy":
            self.device.cancel_move() 
            wav_path = os.path.abspath("audios/reachy/"+ self.name+ "/" + self.audio_path)
            data, samplerate = sf.read(wav_path)
            
            if len(data.shape) > 1:
                data = data.mean(axis=1)
        
            with wave.open(wav_path, "rb") as wf:
                # Duração real do ficheiro
                wav_duration = wf.getnframes() / wf.getframerate()
                    
            end = time.time() + wav_duration + 2
                
            
            self.device.media.play_sound(wav_path)
            while time.time() < end:
                await self.device.async_play_move(emotions.get("come1"), initial_goto_duration=0.1, sound=False)
        
        
            self.device.cancel_move() # Interrompe qualquer movimento residual do duration
            self.device.goto_target(head=create_head_pose(), duration=0.2)

        else: 
            end = time.time() + duration
            while time.time() < end:
                print("RobotSim " + self.name + " is talking!")
                await asyncio.sleep(1.5)
                


    async def idle_animation(self, duration):
        end = time.time() + duration
        yaw = 0
        
        if self.type == "dash": 
            while time.time() < end:
                yaw = min(20,max(-20,yaw+random.randint(-3, 3)))
                await self.device.head_yaw(yaw)
                await asyncio.sleep(random.uniform(0.5, 2.0))
            
        elif self.type == "reachy":    
            self.device.cancel_move() 
            await self.device.async_play_move(emotions.get(random.choice(self.idle_animations_reachy)), initial_goto_duration=0.5, sound=False)
            while time.time() < end:
                await self.device.async_play_move(emotions.get(random.choice(self.idle_animations_reachy)), initial_goto_duration=0.5, sound=False)
                await asyncio.sleep(0.5)

            self.device.cancel_move() # Interrompe qualquer movimento residual do duration
            self.device.goto_target(head=create_head_pose(), duration=0.2)
            
        else: 
            print("RobotSim " + self.name + " is idling!")
            await asyncio.sleep(random.uniform(2.5, 4.0))

            

    async def listening_animation(self, duration):
        end = time.time() + duration
        
        
        if self.type == "dash":  
            
            while time.time() < end:
                self.value_eye_dash += 1
                await self.device.eye(self.value_eye_dash)
                await asyncio.sleep(0.1)
                
        elif self.type == "reachy": 
            self.device.cancel_move() 

            while time.time() < end:
                if self.antenna_angle == 0:
                    self.antenna_angle = 1
                else:
                    self.antenna_angle = 0
                self.device.goto_target(
                        antennas=[-self.antenna_angle, self.antenna_angle],  # Neutral antenna positions (radians)
                        duration=1.0,
                    )
            
                await asyncio.sleep(1.5)

            self.device.cancel_move() # Interrompe qualquer movimento residual do duration
            
        else:
            print("RobotSim " + self.name + " is listening!")
            await asyncio.sleep(1.5)
        

    async def disconnect(self):
        if self.type == "dash": 
            await self.device.disconnect()
            print("Dash " + self.name + " disconnected!")
        elif self.type == "reachy":
            self.device = None
            print("Reachy " + self.name + " disconnected!")
        else:
            print("RobotSim " + self.name + " disconnected!")

    def is_speaking(self):
        return self.state == "speak"
    
    def set_state(self, state):
        self.state = state

    async def stare_to(self, position):
        if(position == self.position):
            pass
        angle = self.look_angles[position]

        
        
        if self.type == "dash": 
            await self.device.head_yaw(0)
            if(angle == 54):
                await self.device.head_yaw(30)
            if(angle == -54):
                await self.device.head_yaw(-30)
            if(angle == 18):
                await self.device.head_yaw(10)
            if(angle == -18):
                await self.device.head_yaw(-10)
            
        elif self.type == "reachy": 
            
            self.device.cancel_move() 
        

            self.device.goto_target(
                    head=create_head_pose(yaw=-angle, degrees=True),
                    duration=1
            )
                            
            await asyncio.sleep(1)
            

        else:
            #print("RobotSim " + self.name + " looking to position" + str(position))
            await asyncio.sleep(1)

    

    async def run_loop(self):
        while True:
            match self.state:
                case "idle":
                    await self.idle_animation(5)
                case "stare":
                    #print("stare")
                    await self.stare_to(self.stare_position)
                    self.state = "listen"
                    self.value_eye_dash = 0
                case "listen":
                    #print("Listening")
                    await self.listening_animation(5)
                case "speak":
                    await self.animete_and_talk(22)
                    self.state = "idle"
                    
                case "stop":
                    self.state = "idle"
                    break
                case _:
                    return "Something's wrong with "+self.name

# %%
import threading
import socketserver
from http.server import BaseHTTPRequestHandler
import asyncio

_loop = None
_queue = None

HTML_control = b"""
<!DOCTYPE html>
<html>
<head>
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>Robot Control</title>
  <style>
    body { background: #0d0d0d; color: white; font-family: sans-serif;
           display: flex; flex-direction: column; align-items: center;
           justify-content: center; min-height: 100vh; margin: 0; gap: 1.2rem; }
    h2  { font-size: 1.1rem; color: #888; font-weight: 400; }
    #status { background: #1a1a1a; border-radius: 12px; padding: 1rem 2rem;
              color: #4ade80; font-size: 1rem; text-align: center; }
    button  { width: 80vw; max-width: 300px; padding: 1.2rem;
              border: none; border-radius: 14px; font-size: 1.1rem;
              font-weight: 600; cursor: pointer; }
    #btn-start { background: #22c55e; color: white; }
    #btn-stop  { background: #ef4444; color: white; }
    #btn-idle  { background: #3b82f6; color: white; }
    #btn-look  { background: #a855f7; color: white; }
  </style>
</head>
<body>
  <h2>Robot Control</h2>
  <div id="status">A aguardar...</div>
  <button id="btn-start" onclick="trigger('start')">INICIAR RESPOSTAS</button>
  <button id="btn-stop"  onclick="trigger('stop')">PARAR</button>
  <button id="btn-idle"  onclick="trigger('idle')">IDLE</button>
  <button id="btn-look"  onclick="trigger('look')">OLHAR PARTICIPANTE</button>
  <script>
    async function trigger(action) {
      document.getElementById('status').textContent = '...';
      const res = await fetch('/trigger/' + action, { method: 'POST' });
      const data = await res.json();
      document.getElementById('status').textContent = data.msg;
    }
  </script>
</body>
</html>
"""

RESPOSTAS = {
    '/trigger/start': b'{"msg": "Iniciado!"}',
    '/trigger/stop':  b'{"msg": "Parado."}',
    '/trigger/idle':  b'{"msg": "Robos em idle."}',
    '/trigger/look':  b'{"msg": "Robos a olhar para o participante."}',
}

class Handler(BaseHTTPRequestHandler):
    def log_message(self, format, *args):
        pass

    def do_GET(self):
        if self.path == '/':
            self.send_response(200)
            self.send_header('Content-Type', 'text/html; charset=utf-8')
            self.end_headers()
            self.wfile.write(HTML_control)
        else:
            self.send_response(404)
            self.end_headers()

    def do_POST(self):
        if self.path not in RESPOSTAS:
            self.send_response(404)
            self.end_headers()
            return

        acao = self.path.split('/')[-1]
        asyncio.run_coroutine_threadsafe(_queue.put(acao), _loop)

        self.send_response(200)
        self.send_header('Content-Type', 'application/json')
        self.send_header('Access-Control-Allow-Origin', '*')
        self.end_headers()
        self.wfile.write(RESPOSTAS[self.path])


def iniciar_servidor(loop, port=5000):
    global _loop, _queue
    _loop = loop
    _queue = asyncio.Queue()

    server = socketserver.TCPServer(('0.0.0.0', port), Handler)
    server.allow_reuse_address = True
    threading.Thread(target=server.serve_forever, daemon=True).start()
    print(f"\nPágina disponível em  http://localhost:{port}")

    return _queue, server

# %%
import json
import threading
import webbrowser
from http.server import BaseHTTPRequestHandler, HTTPServer

_server = None
_state = {}
_lock = threading.Lock()


HTML = """<!DOCTYPE html>
<html lang="pt">
<head>
<meta charset="UTF-8">
<title>Mesa Redonda</title>
<link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;600&family=IBM+Plex+Sans:wght@300;400;500&display=swap" rel="stylesheet">
<style>
*,*::before,*::after{box-sizing:border-box;margin:0;padding:0}
body{
  font-family:'IBM Plex Sans',sans-serif;
  background:#222;
  color:#f0ede8;
  min-height:100vh;
  display:flex;
  flex-direction:column;
  align-items:center;
  justify-content:center;
  padding:32px 16px;
}
.statement{
  font-size:15px;
  font-weight:300;
  color:#d0d0d0;
  text-align:center;
  max-width:600px;
  margin-bottom:48px;
  line-height:1.6;
  letter-spacing:0.01em;
}
.statement strong{
  display:block;
  font-size:11px;
  font-family:'IBM Plex Mono',monospace;
  letter-spacing:0.15em;
  text-transform:uppercase;
  color:#555;
  margin-bottom:8px;
}

/* Mesa redonda */
.table-wrap{
  position:relative;
  width:420px;
  height:420px;
}
.table-circle{
  position:absolute;
  top:50%; left:50%;
  transform:translate(-50%,-50%);
  width:160px; height:160px;
  border-radius:50%;
  border:1px solid #2a2a2a;
  background:#141414;
  display:flex;
  align-items:center;
  justify-content:center;
}
.table-label{
  font-size:10px;
  font-family:'IBM Plex Mono',monospace;
  letter-spacing:0.12em;
  text-transform:uppercase;
  color:#333;
}

/* Robôs */
.robot{
  position:absolute;
  width:110px;
  text-align:center;
  transform:translate(-50%,-50%);
  transition:all .4s ease;
}
.robot-icon{
  width:64px; height:64px;
  border-radius:50%;
  border:2px solid #2a2a2a;
  background:#1a1a1a;
  margin:0 auto 10px;
  display:flex;
  align-items:center;
  justify-content:center;
  font-size:26px;
  transition:all .5s ease;
  position:relative;
}
.robot-icon img{
  width:100%; height:100%;
  border-radius:50%;
  object-fit:cover;
}
.robot-icon::after{
  content:'';
  position:absolute;
  inset:-4px;
  border-radius:50%;
  border:2px solid transparent;
  transition:border-color .5s ease;
}
.robot.agree .robot-icon{
  background:#0d2a1a;
  border-color:#1a5c34;
}
.robot.agree .robot-icon img{
  width:100%; height:100%;
  border-radius:50%;
  object-fit:cover;
}
.robot-icon::after{
  border-color:#1d7a45;
}
.robot.disagree .robot-icon{
  background:#2a0d0d;
  border-color:#5c1a1a;
}
.robot.disagree .robot-icon img{
  width:100%; height:100%;
  border-radius:50%;
  object-fit:cover;
}
.robot-icon::after{
  border-color:#7a1d1d;
}

.robot-name{
  font-size:12px;
  font-family:'IBM Plex Mono',monospace;
  color:#d0d0d0;
  margin-bottom:6px;
  transition:color .4s;
}
.robot.agree .robot-name{ color:#3d9e66; }
.robot.disagree .robot-name{ color:#9e3d3d; }

.robot-badge{
  display:inline-block;
  font-size:10px;
  font-family:'IBM Plex Mono',monospace;
  letter-spacing:0.05em;
  padding:3px 10px;
  border-radius:20px;
  border:1px solid #222;
  color:#d0d0d0;
  background:#111;
  transition:all .5s ease;
  white-space:nowrap;
}
.robot.agree .robot-badge{
  background:#0d2a1a;
  border-color:#1d7a45;
  color:#3dbc78;
}
.robot.disagree .robot-badge{
  background:#2a0d0d;
  border-color:#7a1d1d;
  color:#bc3d3d;
}

#robot-posicao1{ top:62%; left:80%; }
#robot-posicao2{ top:29%; left:70%; }
#robot-posicao3{ top:29%; left:29.8%; }
#robot-posicao4{ top:62%; left:19.5%; }

/* indicador do participante (estático, no fundo) */
.participant{
  position:absolute;
  top:90.5%; left:50%;
  transform:translate(-50%,-50%);
  text-align:center;
}
.participant-icon{
  width:52px; height:52px;
  border-radius:50%;
  border:2px dashed #2a2a2a;
  background:#111;
  margin:0 auto 6px;
  display:flex;
  align-items:center;
  justify-content:center;
  font-size:20px;
}
.participant-label{
  font-size:10px;
  font-family:'IBM Plex Mono',monospace;
  letter-spacing:0.1em;
  text-transform:uppercase;
  color:#333;
}

/* Legenda */
.legend{
  display:flex;
  gap:24px;
  margin-top:40px;
}
.legend-item{
  display:flex;
  align-items:center;
  gap:8px;
  font-size:11px;
  font-family:'IBM Plex Mono',monospace;
  letter-spacing:0.08em;
  color:#444;
}
.legend-dot{
  width:10px; height:10px;
  border-radius:50%;
}
.legend-dot.agree{ background:#1d7a45; }
.legend-dot.disagree{ background:#7a1d1d; }
</style>
</head>
<body>

<div class="statement">
  <strong>Statement em discussão</strong>
  <span id="stmt-text">A carregar...</span>
</div>

<div class="table-wrap" id="table-wrap">
  <div class="table-circle">
    <span class="table-label">Mesa<br>Redonda</span>
  </div>
  <div class="participant">
    <div class="participant-icon">&#128100;</div>
    <div class="participant-label">Participante</div>
  </div>
</div>


<script>

let robots = [];
let rendered = false;

function renderRobots(names){
  const wrap = document.getElementById('table-wrap');
  // manter o círculo central
  const circle = wrap.querySelector('.table-circle');
  wrap.innerHTML = '';
  wrap.appendChild(circle);

  robots = names;
  names.forEach((name, i) => {
    const div = document.createElement('div');
    div.className = 'robot';
    div.id = 'robot-' + name;
    div.innerHTML = `
      <div class="robot-icon"><img src="./images/${name}.jpg" alt="${name}"></div>
      <div class="robot-badge">a pensar...</div>
    `;
    wrap.appendChild(div);
  });
  rendered = true;
}

function updateRobot(name, side, label){
  const el = document.getElementById('robot-' + name);
  if(!el) return;
  el.className = 'robot ' + side;
  el.querySelector('.robot-badge').textContent = label;
}

async function poll(){
  try{
    const r = await fetch('/state');
    const data = await r.json();

    document.getElementById('stmt-text').textContent = data.statement || '';

    if(!rendered && data.robots && data.robots.length){
      renderRobots(data.robots);
    }

    if(data.responses){
      for(const [name, info] of Object.entries(data.responses)){
        updateRobot(name, info.side, info.label);
      }
    }
  } catch(e){}
  setTimeout(poll, 800);
}

poll();
</script>
</body>
</html>"""


def _make_handler():
    class Handler(BaseHTTPRequestHandler):
        def log_message(self, fmt, *args): pass

        def do_GET(self):
            if self.path == "/" or self.path == "/index.html":
                data = HTML.encode("utf-8")
                self.send_response(200)
                self.send_header("Content-Type", "text/html; charset=utf-8")
                self.end_headers()
                self.wfile.write(data)
        
            elif self.path == "/state":
                with _lock:
                    payload = json.dumps(_state).encode("utf-8")
                self.send_response(200)
                self.send_header("Content-Type", "application/json")
                self.end_headers()
                self.wfile.write(payload)
        
            elif self.path.startswith("/images/"):
                # servir imagens da pasta robots/
                file_path = self.path.lstrip("/")  # "robots/Robot1.png"
                try:
                    with open(file_path, "rb") as f:
                        data = f.read()
                    self.send_response(200)
                    self.send_header("Content-Type", "image/png")
                    self.end_headers()
                    self.wfile.write(data)
                except FileNotFoundError:
                    self.send_response(404)
                    self.end_headers()
        
            else:
                self.send_response(404)
                self.end_headers()

        def do_POST(self):
            if self.path == "/update":
                length = int(self.headers.get("Content-Length", 0))
                body = json.loads(self.rfile.read(length))
                robot = body.get("robot", "")
                answer = body.get("answer", "").strip().lower()

                info = SCALE.get(answer, {
                    "label": answer.capitalize(),
                    "side":  "neutral",
                    "value": 0
                })

                with _lock:
                    if "responses" not in _state:
                        _state["responses"] = {}
                    _state["responses"][robot] = info

                self.send_response(200)
                self.send_header("Content-Type", "application/json")
                self.end_headers()
                self.wfile.write(b'{"ok":true}')

            else:
                self.send_response(404)
                self.end_headers()

    return Handler


def start_roundtable(robot_names: list, statement: str, port: int = 8006):
    """Arranca o servidor e abre o browser."""
    global _server, _state
    _state = {
        "statement": statement,
        "robots": robot_names,
        "responses": {}
    }
    _server = HTTPServer(("0.0.0.0", port), _make_handler())
    t = threading.Thread(target=_server.serve_forever, daemon=True)
    t.start()
    print(f"Mesa redonda em http://localhost:{port}")


def update_robot(robot_name: str, answer: str):
    """Chamar quando um robô responde. answer: qualquer string."""
    with _lock:
        if "responses" not in _state:
            _state["responses"] = {}
        _state["responses"][robot_name] = {"label": answer}
    print(f"  -> {robot_name}: {answer}")



def stop_roundtable():
    """Para o servidor."""
    global _server
    if _server:
        _server.shutdown()
        _server = None
        print("Mesa redonda encerrada.")

# %% [markdown]
# ### Articles

# %%
from PIL import Image, ImageDraw, ImageFont
import threading
from http.server import SimpleHTTPRequestHandler, HTTPServer


def crop_center(img, target_w, target_h):
    img_ratio = img.width / img.height
    target_ratio = target_w / target_h

    # cortar largura
    if img_ratio > target_ratio:
        new_width = int(img.height * target_ratio)
        offset = (img.width - new_width) // 2
        img = img.crop((offset, 0, offset + new_width, img.height))
    else:
        new_height = int(img.width / target_ratio)
        offset = (img.height - new_height) // 2
        img = img.crop((0, offset, img.width, offset + new_height))

    return img.resize((target_w, target_h))



def wrap_text(text, font, max_width, draw):
    lines = []
    words = text.split()

    while words:
        line = ""
        while words:
            test_line = line + words[0] + " "
            bbox = draw.textbbox((0, 0), test_line, font=font)
            w = bbox[2] - bbox[0]

            if w <= max_width:
                line = test_line
                words.pop(0)
            else:
                break

        lines.append(line.strip())

    return lines


def criar_card(titulo, quote, imagem_path, output):

    WIDTH, HEIGHT = 540, 540
    
    img = Image.open(imagem_path).convert("RGB")
    img = crop_center(img, WIDTH, HEIGHT)

    # escurecer ligeiramente (melhor leitura)
    black = Image.new("RGB", (WIDTH, HEIGHT), (0, 0, 0))
    img = Image.blend(img, black, 0.8)

    draw = ImageDraw.Draw(img)

    titulo_font = ImageFont.truetype("./Lato/Lato-Bold.ttf", 30)
    quote_font = ImageFont.truetype("./Lato/Lato-Regular.ttf", 20)

    max_width = 500

    titulo_lines = wrap_text(titulo, titulo_font, max_width, draw)

    y = 50

    for line in titulo_lines:
        bbox = draw.textbbox((0, 0), line, font=titulo_font)
        text_width = bbox[2] - bbox[0]

        x = (WIDTH - text_width) / 2

        draw.text((x, y), line, font=titulo_font, fill="white")
        y += 50

    quote_text = f"“{quote}”"
    quote_lines = wrap_text(quote_text, quote_font, max_width, draw)

    line_height = 25
    total_height = len(quote_lines) * line_height

    y_quote = HEIGHT - total_height - 90

    for line in quote_lines:
        bbox = draw.textbbox((0, 0), line, font=quote_font)
        text_width = bbox[2] - bbox[0]

        x = (WIDTH - text_width) / 2

        draw.text((x, y_quote), line, font=quote_font, fill="white")
        y_quote += line_height

    img.save(output)
    print(f"✔ Guardado: {output}")

# %% [markdown]
# ### Virtual agents

# %%
from sentence_transformers import SentenceTransformer, util

_model = None
def get_model(statements):
    global _model
    if _model is None:
        print("A carregar Sentence-BERT...")
        model_sim = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
        embeddings_ref = model_sim.encode(statements[topic], convert_to_tensor=True)
    return model_sim, embeddings_ref
 
 
def find_best_statement(prompt, statements):
    print("Prompt: " + prompt)

    model, embeddings_ref = get_model(statements)
    emb_prompt = model.encode(prompt, convert_to_tensor=True)

    cos_sim = util.cos_sim(emb_prompt, embeddings_ref)[0]
    idx = cos_sim.argmax().item()
    conf = cos_sim[idx].item()
    
    print(f"  → Statement: {idx+1} (score={conf:.2f})")
    if(conf > 0.6):
        return idx+1
    return 7
    
 
 
def get_responses(json_data, topic, statement_id, condition, participant_response):
    """Devolve lista de 4 textos, um por agente, pela ordem do json."""
    if(statement_id == 7):
        return ["(sem resposta)","(sem resposta)","(sem resposta)","(sem resposta)"]
    
    block = json_data[topic][str("virtuals")][str(statement_id)][participant_response][condition]
 
    texts = []
    for entry in block.values():
        # tenta campos comuns — ajusta ao nome real no teu JSON
        
        texts.append(entry["quote"])
 
    while len(texts) < 4:
        texts.append("(sem resposta)")
    return texts[:4]


def make_handler(statements, json_data, topic, condition, participant_response):
    class Handler(SimpleHTTPRequestHandler):
 
        def log_message(self, fmt, *args):
            pass  # silenciar logs

        def do_GET(self):
            with open("chat_virtual.html", "rb") as f:
                data = f.read()
            self.send_response(200)
            self.send_header("Content-Type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(data)

 
        def do_POST(self):
            if self.path == "/ask":
                length = int(self.headers.get("Content-Length", 0))
                body = json.loads(self.rfile.read(length))
                prompt = body.get("prompt", "").strip()
        
                sid = find_best_statement(prompt, statements)
                texts = get_responses(json_data, topic, sid, condition, participant_response)
        
                resp = json.dumps({
                    "statement_id": sid,
                    "statement_text": statements.get(sid, ""),
                    "responses": {
                        "claude":  texts[0],
                        "gpt":     texts[1],
                        "gemini":  texts[2],
                        "mistral": texts[3],
                    }
                }).encode("utf-8")
        
                self.send_response(200)
                self.send_header("Content-Type", "application/json")
                self.send_header("Access-Control-Allow-Origin", "*")
                self.end_headers()
                self.wfile.write(resp)
 
        def do_OPTIONS(self):
            self.send_response(200)
            self.send_header("Access-Control-Allow-Origin", "*")
            self.send_header("Access-Control-Allow-Methods", "POST, GET, OPTIONS")
            self.send_header("Access-Control-Allow-Headers", "Content-Type")
            self.end_headers()
 
    return Handler

# %% [markdown]
# ### Questionários

# %%
import asyncio
import json
import threading
import uuid
import webbrowser
from datetime import datetime
from http.server import BaseHTTPRequestHandler, HTTPServer
from pathlib import Path

RESPONSES_FILE = "responses.json"

# ── Dados dos questionários ───────────────────────────────────────────────────

TOPICS = {
    "economic": {
        "label": "Posições Socioeconómicas — Económico",
        "options": ["Discordo totalmente", "Discordo", "Discordo ligeiramente",
                    "Concordo ligeiramente", "Concordo", "Concordo totalmente"],
        "statements": [
            "O mérito pessoal é suficiente para se ter sucesso em Portugal.",
            "O politicamente correto tornou o mundo monótono.",
            "A qualidade dos serviços de saúde e da educação deve ser garantida pelo governo.",
            "O setor privado é um gestor mais honesto do que o governo.",
            "Quanto menos o governo interferir na sociedade, melhor será o país.",
            "A igualdade social é mais importante do que a liberdade económica.",
            "Os criminosos devem ser punidos com a pena de morte.",
            "O governo deve regulamentar o setor privado para promover o interesse público.",
        ]
    },
    "social": {
        "label": "Posições Socioeconómicas — Social",
        "options": ["Discordo totalmente", "Discordo", "Discordo ligeiramente",
                    "Concordo ligeiramente", "Concordo", "Concordo totalmente"],
        "statements": [
            "As mulheres devem ter o direito de optar pelo aborto.",
            "A legalização e a regulamentação das drogas leves trariam resultados positivos.",
            "Os movimentos em defesa dos direitos das minorias são legítimos.",
            "Apenas os casais heterossexuais devem poder adotar.",
            "A separação entre a Igreja e o Estado em questões jurídicas e políticas é essencial.",
            "O aumento do número de imigrantes em Portugal é necessário e positivo.",
        ]
    },
    "robot_related": {
        "label": "Atitudes em relação aos Robôs",
        "options": ["Discordo totalmente", "Discordo", "Discordo ligeiramente",
                    "Concordo ligeiramente", "Concordo", "Concordo totalmente"],
        "statements": [
            "Os robôs são necessários porque conseguem realizar tarefas demasiado difíceis ou perigosas para as pessoas.",
            "Os robôs podem facilitar a nossa vida.",
            "Atribuir tarefas de rotina aos robôs permite que as pessoas se dediquem a tarefas mais significativas.",
            "As tarefas perigosas devem ser atribuídas, em primeiro lugar, aos robôs.",
            "Os robôs são benéficos para a sociedade, porque ajudam as pessoas.",
            "Os robôs podem tornar-nos ainda mais preguiçosos.",
            "A utilização generalizada de robôs vai tirar empregos às pessoas.",
            "Receio que os robôs incentivem uma menor interação entre os seres humanos.",
            "A robótica é uma das áreas da tecnologia que precisa de ser rigorosamente supervisionada.",
            "A utilização não regulamentada da robótica pode levar a mudanças sociais.",
        ]
    }
}

KNOWLEDGE_BLOCK = {
    "label": "Conhecimento sobre o tema",
    "options": ["Não, de todo", "Muito pouco", "Pouco", "Moderadamente",
                "Neutro", "Razoavelmente", "Bastante", "Muito", "Extremamente"],
    "statements": [
        "Em que medida considera-se bem informado sobre este tema?",
        "Em que medida considera que possui informação sobre este tema?",
        "Em que medida considera que possui conhecimentos especializados sobre este tema?",
        "Em que medida considera que conhece os factos mais relevantes sobre este tema?",
    ]
}

DEMOGRAPHICS_PRE = [
    {"id": "age",         "label": "Idade",               "type": "number"},
    {"id": "gender",      "label": "Identidade de género", "type": "text"},
    {"id": "nationality", "label": "Nacionalidade",        "type": "text"},
    {"id": "university",  "label": "Universidade",         "type": "text"},
    {"id": "course",      "label": "Área de estudo/Curso", "type": "text"},
]

DEMOGRAPHICS_POS = [
    {"id": "party",      "label": "Em que partido votou nas últimas eleições legislativas?", "type": "text"},
    {"id": "ai_freq",    "label": "Nos últimos 6 meses, com que frequência utilizou a IA?",
     "type": "select", "options": ["Não utilizei nos últimos seis meses", "Menos de uma vez por mês",
                                    "Cerca de uma vez por mês", "Cerca de duas vezes por mês",
                                    "Cerca de três vezes por mês", "Semanalmente", "Diariamente"]},
    {"id": "robot_freq", "label": "Nos últimos 6 meses, com que frequência interagiu com robôs?",
     "type": "select", "options": ["Não interagi nos últimos seis meses", "Menos de uma vez por mês",
                                    "Cerca de uma vez por mês", "Cerca de duas vezes por mês",
                                    "Cerca de três vezes por mês", "Semanalmente", "Diariamente"]},
    {"id": "robot_types", "label": "Com que tipos de robôs já interagiste?", "type": "text"},
]


# ── Carregar / guardar respostas ──────────────────────────────────────────────

def load_responses():
    if Path(RESPONSES_FILE).exists():
        with open(RESPONSES_FILE, "r", encoding="utf-8") as f:
            return json.load(f)
    return {}

def save_responses(data):
    with open(RESPONSES_FILE, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)


# ── Gerar HTML ────────────────────────────────────────────────────────────────

def build_html(phase, topic, participant_id):
    is_pre = phase == "pre"
    title = "Questionário Inicial" if is_pre else "Questionário Final"
    topic_data = TOPICS[topic]

    # Blocos de statements (Likert)
    def likert_block(block_label, statements, options, topic):
        opts_html = "".join(
            f'<div class="opt-label">{o}</div>' for o in options
        )
        rows = ""
        for i, stmt in enumerate(statements):
            cells = "".join(
                f'<td><label class="radio-wrap"><input type="radio" name="q_{topic}_{i+1}" value="{j+1}" required><span class="dot"></span></label></td>'
                for j in range(len(options))
            )
            rows += f"""
            <tr class="stmt-row">
              <td class="stmt-text">{stmt}</td>
              {cells}
            </tr>"""
        return f"""
        <div class="block">
          <h2 class="block-title">{block_label}</h2>
          <div class="table-wrap">
            <table class="likert">
              <thead>
                <tr>
                  <th></th>
                  {opts_html.replace('<div class="opt-label">', '<th class="opt-col">').replace('</div>', '</th>')}
                </tr>
              </thead>
              <tbody>{rows}</tbody>
            </table>
          </div>
        </div>"""

    # Bloco de demographics
    def demo_block(fields):
        inputs = ""
        for f in fields:
            if f["type"] == "select":
                opts = "".join(f'<option value="{o}">{o}</option>' for o in f["options"])
                inputs += f'<div class="field"><label>{f["label"]}</label><select name="{f["id"]}" required><option value="">-- seleciona --</option>{opts}</select></div>'
            else:
                inputs += f'<div class="field"><label>{f["label"]}</label><input type="{f["type"]}" name="{f["id"]}" required></div>'
        return f'<div class="block"><h2 class="block-title">Dados Pessoais</h2>{inputs}</div>'

    # Montar blocos consoante fase
    if is_pre:
        blocks = (
            demo_block(DEMOGRAPHICS_PRE) +
            likert_block(topic_data["label"], topic_data["statements"], topic_data["options"], topic) +
            likert_block(KNOWLEDGE_BLOCK["label"], KNOWLEDGE_BLOCK["statements"], KNOWLEDGE_BLOCK["options"],"knowledge")
        )
    else:
        blocks = (
            likert_block(topic_data["label"], topic_data["statements"], topic_data["options"], topic) +
            demo_block(DEMOGRAPHICS_POS)
        )

    return f"""<!DOCTYPE html>
<html lang="pt">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>{title}</title>
<link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;600&family=IBM+Plex+Sans:wght@400;500;600&display=swap" rel="stylesheet">
<style>
*, *::before, *::after {{ box-sizing: border-box; margin: 0; padding: 0; }}

:root {{
  --bg: #f4f1ec;
  --surface: #ffffff;
  --border: #d6d0c8;
  --text: #1a1816;
  --muted: #7a746e;
  --accent: #2a5298;
  --accent-light: #e8eef7;
  --dot: #2a5298;
  --radius: 8px;
}}

body {{
  font-family: 'IBM Plex Sans', sans-serif;
  background: var(--bg);
  color: var(--text);
  min-height: 100vh;
  padding: 40px 20px 80px;
}}

.container {{
  max-width: 860px;
  margin: 0 auto;
}}

header {{
  margin-bottom: 40px;
  padding-bottom: 24px;
  border-bottom: 2px solid var(--text);
}}

.phase-tag {{
  font-family: 'IBM Plex Mono', monospace;
  font-size: 11px;
  font-weight: 600;
  letter-spacing: 0.15em;
  text-transform: uppercase;
  color: var(--muted);
  margin-bottom: 8px;
}}

h1 {{
  font-size: 28px;
  font-weight: 600;
  line-height: 1.2;
}}

.pid {{
  font-family: 'IBM Plex Mono', monospace;
  font-size: 11px;
  color: var(--muted);
  margin-top: 8px;
}}

/* Blocks */
.block {{
  background: var(--surface);
  border: 1px solid var(--border);
  border-radius: var(--radius);
  padding: 28px;
  margin-bottom: 24px;
}}

.block-title {{
  font-size: 13px;
  font-weight: 600;
  letter-spacing: 0.08em;
  text-transform: uppercase;
  color: var(--muted);
  margin-bottom: 20px;
  padding-bottom: 12px;
  border-bottom: 1px solid var(--border);
}}

/* Likert table */
.table-wrap {{ overflow-x: auto; }}

.likert {{
  width: 100%;
  border-collapse: collapse;
  font-size: 14px;
}}

.likert thead th {{
  font-size: 11px;
  font-weight: 500;
  color: var(--muted);
  text-align: center;
  padding: 0 6px 12px;
  line-height: 1.3;
}}

.likert th:first-child {{ text-align: left; width: 36%; }}
.opt-col {{ min-width: 60px; }}

.stmt-row {{ border-top: 1px solid var(--border); }}
.stmt-row:hover {{ background: #faf9f7; }}

.stmt-text {{
  padding: 14px 12px 14px 0;
  line-height: 1.5;
  font-size: 14px;
  vertical-align: middle;
}}

.likert td {{
  text-align: center;
  vertical-align: middle;
  padding: 10px 4px;
}}

.radio-wrap {{ cursor: pointer; display: inline-flex; }}
.radio-wrap input {{ display: none; }}

.dot {{
  width: 20px; height: 20px;
  border-radius: 50%;
  border: 2px solid var(--border);
  display: block;
  transition: all .15s;
  background: white;
}}

.radio-wrap input:checked + .dot {{
  background: var(--dot);
  border-color: var(--dot);
  box-shadow: 0 0 0 3px var(--accent-light);
}}

.radio-wrap:hover .dot {{ border-color: var(--accent); }}

/* Demographics fields */
.field {{ margin-bottom: 18px; }}
.field:last-child {{ margin-bottom: 0; }}

.field label {{
  display: block;
  font-size: 13px;
  font-weight: 500;
  margin-bottom: 6px;
  color: var(--text);
}}

.field input, .field select {{
  width: 100%;
  padding: 10px 12px;
  border: 1px solid var(--border);
  border-radius: var(--radius);
  font-family: 'IBM Plex Sans', sans-serif;
  font-size: 14px;
  background: var(--bg);
  color: var(--text);
  transition: border-color .15s;
}}

.field input:focus, .field select:focus {{
  outline: none;
  border-color: var(--accent);
  background: white;
}}

/* Submit */
.submit-wrap {{
  text-align: center;
  margin-top: 32px;
}}

.btn {{
  font-family: 'IBM Plex Sans', sans-serif;
  font-size: 15px;
  font-weight: 600;
  padding: 14px 48px;
  background: var(--text);
  color: white;
  border: none;
  border-radius: var(--radius);
  cursor: pointer;
  transition: opacity .15s;
}}
.btn:hover {{ opacity: 0.85; }}
.btn:disabled {{ opacity: 0.4; cursor: not-allowed; }}

.msg-ok {{
  display: none;
  margin-top: 20px;
  font-size: 14px;
  color: #2a7a2a;
  font-weight: 500;
}}
</style>
</head>
<body>
<div class="container">
  <header>
    <div class="phase-tag">{"Questionário Inicial" if is_pre else "Questionário Final"} &mdash; {topic_data["label"]}</div>
    <h1>{"Bem-vindo ao estudo." if is_pre else "Estamos quase a terminar."}</h1>
    <div class="pid">ID: {participant_id}</div>
  </header>

  <form id="qform">
    <input type="hidden" name="participant_id" value="{participant_id}">
    <input type="hidden" name="phase" value="{phase}">
    <input type="hidden" name="topic" value="{topic}">
    {blocks}
    <div class="submit-wrap">
      <button type="submit" class="btn" id="submit-btn">Submeter respostas</button>
      <div class="msg-ok" id="msg-ok">Respostas guardadas. Pode fechar esta janela.</div>
    </div>
  </form>
</div>

<script>
document.getElementById('qform').addEventListener('submit', async function(e) {{
  e.preventDefault();
  const btn = document.getElementById('submit-btn');
  btn.disabled = true;
  btn.textContent = 'A guardar...';

  const fd = new FormData(this);
  const data = {{}};
  for (const [k, v] of fd.entries()) data[k] = v;

  // Recolher radios manualmente (FormData so inclui os checked)
  document.querySelectorAll('input[type=radio]:checked').forEach(r => {{
    data[r.name] = r.value;
  }});

  try {{
    const r = await fetch('/submit', {{
      method: 'POST',
      headers: {{'Content-Type': 'application/json'}},
      body: JSON.stringify(data)
    }});
    if (r.ok) {{
      document.getElementById('msg-ok').style.display = 'block';
      btn.textContent = 'Submetido';
    }} else {{
      btn.disabled = false;
      btn.textContent = 'Submeter respostas';
      alert('Erro ao guardar. Tenta novamente.');
    }}
  }} catch(err) {{
    btn.disabled = false;
    btn.textContent = 'Submeter respostas';
    alert('Erro de ligacao: ' + err.message);
  }}
}});
</script>
</body>
</html>"""


# ── Handler HTTP ──────────────────────────────────────────────────────────────

def make_handler_quest(phase, topic, participant_id, done_event):
    class Handler(BaseHTTPRequestHandler):
        def log_message(self, fmt, *args): pass

        def do_GET(self):
            html = build_html(phase, topic, participant_id).encode("utf-8")
            self.send_response(200)
            self.send_header("Content-Type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(html)

        def do_POST(self):
            if self.path == "/submit":
                length = int(self.headers.get("Content-Length", 0))
                body = json.loads(self.rfile.read(length))

                # Guardar no JSON
                all_data = load_responses()
                pid = body.get("participant_id", participant_id)
                if(phase == "pre"):
                    if pid not in all_data:
                        all_data[pid] = {}
                    all_data[pid] = {
                        "timestamp": datetime.now().isoformat(),
                        "topic": topic,
                        "pre": body
                    }
                else:
                    all_data[pid]["pro"] = body
                save_responses(all_data)
                print(f"  -> Respostas do {phase} guardadas para {pid}")

                self.send_response(200)
                self.send_header("Content-Type", "application/json")
                self.end_headers()
                self.wfile.write(b'{"ok": true}')

                # Sinalizar que terminou
                done_event.set()
            else:
                self.send_response(404)
                self.end_headers()

    return Handler


# ── Ponto de entrada ──────────────────────────────────────────────────────────

def run_questionnaire_sync(phase, topic, participant_id=None, port=8001):
    import uuid, threading, webbrowser
    from http.server import HTTPServer

    if participant_id is None:
        participant_id = str(uuid.uuid4())

    done_event = threading.Event()
    handler = make_handler_quest(phase, topic, participant_id, done_event)
    server = HTTPServer(("0.0.0.0", port), handler)

    t = threading.Thread(target=server.serve_forever, daemon=True)
    t.start()

    webbrowser.open(f"http://127.0.0.1:{port}")
    print(f"Abre http://127.0.0.1:{port} se o browser nao abrir sozinho")

    done_event.wait()  # bloqueia até o participante submeter
    server.shutdown()
    print(f"Questionario {phase} concluido.")
    return participant_id

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Step 1 - Randomization of the experiment and pre-questionnaire
# Run this cell to randomize the experience and start the pre-questionnaire

# %%
import random
import json


statements = {
    "economic":[],
    "social":[],
    "robot_related":[
    "Os robôs são benéficos para a sociedade, porque ajudam as pessoas.",
    "Atribuir tarefas de rotina aos robôs permite que as pessoas se dediquem a tarefas mais significativas.",
    "Receio que os robôs incentivem uma menor interação entre os seres humanos.",
    "As tarefas perigosas devem ser atribuídas, em primeiro lugar, aos robôs.",
    "A utilização generalizada de robôs vai tirar empregos às pessoas.",
    "A utilização não regulamentada da robótica pode levar a mudanças sociais.",
    "Acabou esta discussão, obrigado a todos."]
}


#topics = ["economic", "social", "robot_related"]
topics = [ "robot_related"]
with open('matrix.json', encoding='utf-8') as f:
    json_data = json.load(f)



participant_id = input("\nID do participante(se for um novo participante, não preencher")

if(participant_id == ""):

    topic = random.choice(topics)
    
    print("Tópico: "+ topic)
    
    participant_id = run_questionnaire_sync("pre", topic)
    
    questionnaire_to_discussion = {
        "robot_related":{
            1: "q_robot_related_5",
            2: "q_robot_related_3",
            3: "q_robot_related_8",
            4: "q_robot_related_4",
            5: "q_robot_related_7",
            6: "q_robot_related_10",
        }
    }

    participant_responses = {}

    with open('responses.json') as f:
        participant_data = json.load(f)
    
    for qid in questionnaire_to_discussion[topic].keys():
        id_questionnaire = questionnaire_to_discussion[topic][qid]
        if(topic == "robot_related"):
            if(int(participant_data[participant_id]["pre"][id_questionnaire]) < 4):
                participant_responses[qid] = "participant_disagree"
            elif(int(participant_data[participant_id]["pre"][id_questionnaire]) >= 4):
                participant_responses[qid] = "participant_agree"
            
    
    print("\nResposta do participante:")
    for qid in participant_responses.keys():
        print("Statement " + str(qid) + ", resposta "+ participant_responses[qid])
    
    
            
    dic_aux = {
        "robots": ["all_disagree", "half_disagree"],
        "virtuals": ["all_disagree", "half_disagree"],
        "articles": ["all_disagree", "half_disagree"]
    }
        
    ids = [1, 2, 3, 4, 5, 6]
    random.shuffle(ids)  # mistura os IDs
        
    resultado = {}
    i = 0
        
    for key, values in dic_aux.items():
        resultado[key] = {}
        for v in values:
            resultado[key][v] = ids[i]
            i += 1
                
    conditions = []
        
    for categoria, condicoes in resultado.items():
        for condicao, statement_id in condicoes.items():
                
            conditions.append([str(statement_id),categoria,condicao])
    
    random.shuffle(conditions)
    participant_data[participant_id]["rounds"] = {}
    print("\nOs statements vão ser discutidos na seguinte ordem: ")
    for num, (statement_id,agents,condition) in enumerate(conditions):
        participant_data[participant_id]["rounds"][num] = {}
        participant_data[participant_id]["rounds"][num]["statement_id"] = statement_id
        participant_data[participant_id]["rounds"][num]["agents"] = agents
        participant_data[participant_id]["rounds"][num]["condition"] = condition
        participant_data[participant_id]["rounds"][num]["participant_opinion"] = participant_responses[int(statement_id)]
        print(f"O statement {statement_id} vai ser discutido com {agents} na condição {condition}.")

    save_responses(participant_data)


else:
    try:
        topic = participant_data[participant_id]["topic"]
        
    except:
        print("ID de participante não existe... Volta a correr a cell e introduz um ID válido ou começa um novo participante.")
# Out:
# ID do participante(se for um novo participante, não preencher
# Tópico: robot_related
# Abre http://127.0.0.1:8001 se o browser nao abrir sozinho
#   -> Respostas do pre guardadas para 59babe2c-b31a-4190-954a-1caa4644a899
# Questionario pre concluido.
#
# Resposta do participante:
# Statement 1, resposta participant_disagree
# Statement 2, resposta participant_disagree
# Statement 3, resposta participant_agree
# Statement 4, resposta participant_agree
# Statement 5, resposta participant_disagree
# Statement 6, resposta participant_agree
#
# Os statements vão ser discutidos na seguinte ordem:
# O statement 1 vai ser discutido com robots na condição all_disagree.
# O statement 2 vai ser discutido com articles na condição all_disagree.
# O statement 6 vai ser discutido com virtuals na condição all_disagree.
# O statement 3 vai ser discutido com virtuals na condição half_disagree.
# O statement 4 vai ser discutido com robots na condição half_disagree.
# ...

# %% [markdown]
# ### Step 2 - Experiment Rounds

# %% [markdown]
# Run this cell every round

# %%
with open('responses.json') as f:
    participant_data = json.load(f)

conditions = []
        
for key in participant_data[participant_id]["rounds"].keys():
    statement_id = participant_data[participant_id]["rounds"][key]["statement_id"]
    agents = participant_data[participant_id]["rounds"][key]["agents"]
    condition = participant_data[participant_id]["rounds"][key]["condition"]
    participant_response = participant_data[participant_id]["rounds"][key]["participant_opinion"]
    conditions.append([statement_id, agents, condition, participant_response])

i = 1
for statement_id,agents,condition,participant_response in conditions:
    print(f"{i} - O statement {statement_id} vai ser discutido com {agents} na condição {condition} - {participant_response}.")
    i+=1
r = input("\nEscolhe qual das rondas queres fazer:")


print("\nVamos começar...")
statement_id,agents,condition, participant_response = conditions[int(r)-1]


print("\nStatement: " + statement_id)

print("\nA resposta do participante foi " + participant_response)
        
if agents == "robots":
    print("\nColocar os robos seguintes na mesa: ")
    robots = {}

    #robots["Robot1"] = Robot("Robot1","reachy")
    #robots["Robot2"] = Robot("Robot2","reachy")
    #robots["Robot7"] = Robot("Robot7","dash")
    #robots["Robot8"] = Robot("Robot8","dash")
    
    #Descomentar quando for para usar os robos reais
    for robot in json_data[topic][str(agents)][statement_id][participant_response][condition].keys():
        typer = json_data[topic][str(agents)][statement_id][participant_response][condition][robot]["type"]
        print(typer)
        position = input("\nEm que posição está o "+robot+"?(1-4)")
        robots[robot] = Robot(robot,"", int(position)) #mudar para typer
        
        

    for robot in json_data[topic][str(agents)][statement_id][participant_response][condition].keys():
        robots[robot].change_audio(json_data[topic][str(agents)][statement_id][participant_response][condition][robot]["audio_path"])
    

    input("\nCarrega Enter para continuar, quando os robos estiverem a postos e ligados...")

    print("\nA conectar os robos...")

    while True:
        for robot in robots.values():
            if not robot.is_connected():
                await robot.connect()
        all_connected = all(robot.is_connected() for robot in robots.values())
        if all_connected:
            break

    for robot in robots.values():
        print(str(robot.name) + "-" + str(robot.is_connected()))
    
    print("\nRobos connectados")
    print("\nA iniciar os robos...")
    for robot in robots.values():
        asyncio.create_task(robot.run_loop())

    start_roundtable(["posicao1", "posicao2", "posicao3", "posicao4"], statements[topic][int(statement_id)])

    print("\nRobos iniciados... O participante pode entrar na sala.")
             
    loop = asyncio.get_event_loop()
    queue, server = iniciar_servidor(loop, port=8005)

    # 2. Robos olham para o participante
    print("Carrega OLHAR para os robos olharem para o participante...")
    while await queue.get() != 'look':
        pass
    for robot in robots.values():
        robot.stare_position = 5
        robot.set_state("stare")

    # 3. Robos respondem
    print("Carrega INICIAR para os robos começarem a falar...")
    while await queue.get() != 'start':
        pass
    for robot in robots.values():
        talking_position = robot.position
        robot.set_state("speak")
        await asyncio.sleep(1)
        for robot_st in robots.values():
            if robot_st.name != robot.name:
                robot_st.stare_position = talking_position
                robot_st.set_state("stare")
        while robot.is_speaking():
            await asyncio.sleep(1)
        update_robot("posicao"+str(talking_position), str(json_data[topic][str(agents)][statement_id][participant_response][condition][robot.name]["vote"])+" "+json_data[topic][str(agents)][statement_id][participant_response][condition][robot.name]["vote_label"])

    # 4. Olham para o participante de novo
    print("Carrega OLHAR para os robos olharem para o participante de novo, enquanto fala...")
    while await queue.get() != 'look':
        pass
    for robot in robots.values():
        robot.stare_position = 5
        robot.set_state("stare")

    # 5. Idle
    print("Carrega IDLE para terminar...")
    while await queue.get() != 'idle':
        pass
    for robot in robots.values():
        robot.set_state("idle")    

    print("Carrega STOP para terminar...")
    while await queue.get() != 'stop':
        pass
    server.shutdown()
    server.server_close()
    print("Servidor parado.")
    
    for robot in robots.values():
        robot.set_state("stop")

    for robot in robots.values():
        await robot.disconnect()

    stop_roundtable()

if agents == "articles":

    print("\nA criar as imagens...")
    for i, article in enumerate(json_data[topic][str(agents)][statement_id][participant_response][condition].keys()):

        criar_card(json_data[topic][str(agents)][statement_id][participant_response][condition][article]["title"], json_data[topic][str(agents)][statement_id][participant_response][condition][article]["quote"], "./articles/background/"+json_data[topic][str(agents)][statement_id][participant_response][condition][article]["img_path"], f"./articles/card_{i+1}.png")
    
    

    html = """
    <!DOCTYPE html>
    <html lang="pt">
    <head>
        <meta charset="UTF-8">
        <title>Notícias</title>
    </head>
    <style>
    body {
        margin: 0;
        background: #111;
        display: flex;
        justify-content: center;
        align-items: center;
    }
    .grid {
        display: grid;
        grid-template-columns: 1fr 1fr;
        gap: 20px;
        width: 90vw;
        max-width: 900px;
    }
    img {
        width: 100%;
        height: auto;
        border-radius: 12px;
    }
    </style>
    </head>
    <body>
    
    <div class="grid">
        <img src="./articles/card_1.png">
        <img src="./articles/card_2.png">
        <img src="./articles/card_3.png">
        <img src="./articles/card_4.png">
    </div>
    
    </body>
    </html>
    """
    
    with open("index.html", "w") as f:
        f.write(html)

    PORT = 8003
    server = None
    
    
    def start_server():
        global server
        server = HTTPServer(("0.0.0.0", PORT), SimpleHTTPRequestHandler)
        print(f"Servidor a correr em http://localhost:{PORT}")
        server.serve_forever()
    
    
    # arrancar servidor
    thread = threading.Thread(target=start_server)
    thread.start()
    
    # esperar input
    input("👉 Carrega ENTER para parar o servidor...\n")
    
    # parar servidor
    if server:
        print("A parar servidor...")
        server.shutdown()
        server.server_close()
        print("Servidor parado.")

if agents == "virtuals":


    PORT = 8002
    server = None
    
    
    def start_server():
        global server
        server = HTTPServer(("0.0.0.0", PORT), make_handler(statements, json_data, topic, condition, participant_response))
        print(f"Servidor a correr em http://localhost:{PORT}")
        server.serve_forever()
    
    
    # arrancar servidor
    thread = threading.Thread(target=start_server)
    thread.start()



    # esperar input
    input("👉 Carrega ENTER para parar o servidor...\n")
    
    # parar servidor
    if server:
        print("A parar servidor...")
        server.shutdown()
        server.server_close()
        print("Servidor parado.")
# Out:
# 1 - O statement 1 vai ser discutido com robots na condição all_disagree - participant_disagree.
# 2 - O statement 2 vai ser discutido com articles na condição all_disagree - participant_disagree.
# 3 - O statement 6 vai ser discutido com virtuals na condição all_disagree - participant_agree.
# 4 - O statement 3 vai ser discutido com virtuals na condição half_disagree - participant_agree.
# 5 - O statement 4 vai ser discutido com robots na condição half_disagree - participant_agree.
# 6 - O statement 5 vai ser discutido com articles na condição half_disagree - participant_disagree.
# Escolhe qual das rondas queres fazer: 2
# Vamos começar...
#
# Statement: 2
#
# A resposta do participante foi participant_disagree
#
# A criar as imagens...
# dict_keys(['1', '2', '3', '4', '5', '6'])
# ✔ Guardado: ./articles/card_1.png
# ✔ Guardado: ./articles/card_2.png
# ✔ Guardado: ./articles/card_3.png
# ✔ Guardado: ./articles/card_4.png
# Servidor a correr em http://localhost:8003
# ...

# %% [markdown]
# ### Step 3 - Post-questionnaire
# Run this code to start the post-questionnaire

# %%
participant_id = input("Introduz o ID do participante:")
with open('responses.json') as f:
    participant_data = json.load(f)

    
run_questionnaire_sync("pro", participant_data[participant_id]["topic"], participant_id)
