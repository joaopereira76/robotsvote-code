# %%
run_questionnaire_sync("pre", "robot-related")
# Out:
# Abre http://127.0.0.1:8001 se o browser nao abrir sozinho
#   -> Respostas do pre guardadas para afd3a50c-ef35-47ab-b6d0-1746faf724c4
# Questionario pre concluido.
# 'afd3a50c-ef35-47ab-b6d0-1746faf724c4'

# %%
run_questionnaire_sync("pro", "robot-related", participant_id)
# Out:
# Abre http://127.0.0.1:8001 se o browser nao abrir sozinho
#   -> Respostas do pro guardadas para 533221ea-732a-4632-927b-f1189e3b6fd3
# Questionario pro concluido.
# '533221ea-732a-4632-927b-f1189e3b6fd3'
